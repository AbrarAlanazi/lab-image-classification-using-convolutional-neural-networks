# %% [markdown]
# # Lab : Image Classification using Convolutional Neural Networks
#
# At the end of this laboratory, you would get familiarized with
#
# *   Creating deep networks using Keras
# *   Steps necessary in training a neural network
# *   Prediction and performance analysis using neural networks
#
# ---

# %% [markdown]
# # **In case you use a colaboratory environment**
# By default, Colab notebooks run on CPU.
# You can switch your notebook to run with GPU.
#
# In order to obtain access to the GPU, you need to choose the tab Runtime and then select “Change runtime type” as shown in the following figure:
#
# ![Changing runtime](https://miro.medium.com/max/747/1*euE7nGZ0uJQcgvkpgvkoQg.png)
#
# When a pop-up window appears select GPU. Ensure “Hardware accelerator” is set to GPU.

# %% [markdown]
# # **Working with a new dataset: CIFAR-10**
#
# The CIFAR-10 dataset consists of 60000 32x32 colour images in 10 classes, with 6000 images per class. There are 50000 training images and 10000 test images. More information about CIFAR-10 can be found [here](https://www.cs.toronto.edu/~kriz/cifar.html).
#
# In Keras, the CIFAR-10 dataset is also preloaded in the form of four Numpy arrays. x_train and y_train contain the training set, while x_test and y_test contain the test data. The images are encoded as Numpy arrays and their corresponding labels ranging from 0 to 9.
#
# Your task is to:
#
# *   Visualize the images in CIFAR-10 dataset. Create a 10 x 10 plot showing 10 random samples from each class.
# *   Convert the labels to one-hot encoded form.
# *   Normalize the images.

# %%
import numpy as np
import matplotlib.pyplot as plt
from tensorflow.keras.datasets import cifar10
from tensorflow.keras.utils import to_categorical

# Load CIFAR-10 dataset
(x_train, y_train), (x_test, y_test) = cifar10.load_data()

# %%
# Your code here :
# Visualize the images in CIFAR-10 dataset
class_names = ["Airplane", "Automobile", "Bird", "Cat", "Deer", "Dog", "Frog", "Horse", "Ship", "Truck"]

# Crear una figura con 10 filas y 10 columnas
fig, axes = plt.subplots(10, 10, figsize=(10, 10))
fig.suptitle("Sample Images from CIFAR-10", fontsize=16)

# Dibujar 10 imágenes aleatorias de cada clase
for i in range(10):  # Para cada clase
    indices = np.where(y_train.flatten() == i)[0]  # Obtener índices de la clase i
    random_indices = np.random.choice(indices, 10, replace=False)  # Elegir 10 imágenes al azar

    for j, idx in enumerate(random_indices):  # Iterar sobre imágenes
        ax = axes[i, j]
        ax.imshow(x_train[idx])
        ax.axis("off")
        if j == 0:
            ax.set_ylabel(class_names[i], fontsize=12)

plt.show()

# Normalizar imágenes (convertir valores de 0-255 a 0-1)
x_train = x_train.astype("float32") / 255.0
x_test = x_test.astype("float32") / 255.0

# Convertir etiquetas a formato one-hot encoding
y_train = to_categorical(y_train, num_classes=10)
y_test = to_categorical(y_test, num_classes=10)

# Ver forma de los datos después de normalizar
print(f"x_train shape: {x_train.shape}, y_train shape: {y_train.shape}")
print(f"x_test shape: {x_test.shape}, y_test shape: {y_test.shape}")
# Out:
# x_train shape: (50000, 32, 32, 3), y_train shape: (50000, 10)
# x_test shape: (10000, 32, 32, 3), y_test shape: (10000, 10)

# %% [markdown]
# ## Define the following model (same as the one in tutorial)
#
# For the convolutional front-end, start with a single convolutional layer with a small filter size (3,3) and a modest number of filters (32) followed by a max pooling layer.
#
# Use the input as (32,32,3).
#
# The filter maps can then be flattened to provide features to the classifier.
#
# Use a dense layer with 100 units before the classification layer (which is also a dense layer with softmax activation).

# %%
from keras.backend import clear_session
clear_session()

# %%
# Your code here :
from keras.models import Sequential
from keras.layers import Conv2D, MaxPooling2D, Flatten, Dense

# Define the model
model = Sequential()

# Convolutional front-end
model.add(Conv2D(32, (3, 3), activation='relu', input_shape=(32, 32, 3)))
model.add(MaxPooling2D(pool_size=(2, 2)))

# Classifier
model.add(Flatten())
model.add(Dense(100, activation='relu'))
model.add(Dense(10, activation='softmax'))

model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ conv2d (Conv2D)                      │ (None, 30, 30, 32)          │             896 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d (MaxPooling2D)         │ (None, 15, 15, 32)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ flatten (Flatten)                    │ (None, 7200)                │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense (Dense)                        │ (None, 100)                 │         720,100 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_1 (Dense)                      │ (None, 10)                  │           1,010 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 722,006 (2.75 MB)
#  Trainable params: 722,006 (2.75 MB)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# *   Compile the model using categorical_crossentropy loss, SGD optimizer and use 'accuracy' as the metric.
# *   Use the above defined model to train CIFAR-10 and train the model for 50 epochs with a batch size of 512.

# %%
# Your code here :
from keras.optimizers import SGD

# Compile the model
model.compile(loss='categorical_crossentropy', optimizer=SGD(), metrics=['accuracy'])

# Train the model
model.fit(x_train, y_train, epochs=50, batch_size=512, validation_data=(x_test, y_test))
# Out:
# Epoch 1/50
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 25ms/step - accuracy: 0.1722 - loss: 2.2622 - val_accuracy: 0.2341 - val_loss: 2.1511
# Epoch 2/50
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 4s 14ms/step - accuracy: 0.2519 - loss: 2.1173 - val_accuracy: 0.2891 - val_loss: 2.0364
# Epoch 3/50
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - accuracy: 0.2970 - loss: 2.0100 - val_accuracy: 0.3220 - val_loss: 1.9466
# Epoch 4/50
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.3245 - loss: 1.9338 - val_accuracy: 0.3120 - val_loss: 1.9233
# Epoch 5/50
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.3467 - loss: 1.8796 - val_accuracy: 0.3482 - val_loss: 1.8610
# Epoch 6/50
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.3568 - loss: 1.8481 - val_accuracy: 0.3559 - val_loss: 1.8352
# Epoch 7/50
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.3705 - loss: 1.8127 - val_accuracy: 0.3681 - val_loss: 1.7930
# Epoch 8/50
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.3752 - loss: 1.7868 - val_accuracy: 0.3859 - val_loss: 1.7631
# Epoch 9/50
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.3931 - loss: 1.7593 - val_accuracy: 0.3854 - val_loss: 1.7509
# Epoch 10/50
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.3940 - loss: 1.7373 - val_accuracy: 0.3925 - val_loss: 1.7250
# Epoch 11/50
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - accuracy: 0.4001 - loss: 1.7207 - val_accuracy: 0.4041 - val_loss: 1.7028
# Epoch 12/50
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.4081 - loss: 1.6896 - val_accuracy: 0.4212 - val_loss: 1.6639
# Epoch 13/50
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.4180 - loss: 1.6726 - val_accuracy: 0.4213 - val_loss: 1.6585
# Epoch 14/50
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.4190 - loss: 1.6700 - val_accuracy: 0.4234 - val_loss: 1.6485
# Epoch 15/50
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.4272 - loss: 1.6342 - val_accuracy: 0.4225 - val_loss: 1.6330
# Epoch 16/50
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.4345 - loss: 1.6170 - val_accuracy: 0.4340 - val_loss: 1.6112
# Epoch 17/50
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.4415 - loss: 1.5943 - val_accuracy: 0.4309 - val_loss: 1.6060
# Epoch 18/50
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.4505 - loss: 1.5744 - val_accuracy: 0.4562 - val_loss: 1.5558
# Epoch 19/50
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.4531 - loss: 1.5591 - val_accuracy: 0.4570 - val_loss: 1.5391
# Epoch 20/50
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.4646 - loss: 1.5329 - val_accuracy: 0.4682 - val_loss: 1.5274
# Epoch 21/50
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.4686 - loss: 1.5238 - val_accuracy: 0.4692 - val_loss: 1.5072
# Epoch 22/50
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.4740 - loss: 1.5044 - val_accuracy: 0.4368 - val_loss: 1.5573
# Epoch 23/50
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.4744 - loss: 1.5013 - val_accuracy: 0.4547 - val_loss: 1.5504
# Epoch 24/50
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.4822 - loss: 1.4763 - val_accuracy: 0.4803 - val_loss: 1.4744
# Epoch 25/50
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.4868 - loss: 1.4667 - val_accuracy: 0.4771 - val_loss: 1.4792
# Epoch 26/50
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.4930 - loss: 1.4486 - val_accuracy: 0.4957 - val_loss: 1.4444
# Epoch 27/50
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.4941 - loss: 1.4348 - val_accuracy: 0.4906 - val_loss: 1.4374
# Epoch 28/50
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.5014 - loss: 1.4239 - val_accuracy: 0.4858 - val_loss: 1.4626
# Epoch 29/50
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.5101 - loss: 1.4113 - val_accuracy: 0.5026 - val_loss: 1.4119
# Epoch 30/50
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.5066 - loss: 1.3992 - val_accuracy: 0.4979 - val_loss: 1.4148
# Epoch 31/50
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.5106 - loss: 1.3937 - val_accuracy: 0.4864 - val_loss: 1.4581
# Epoch 32/50
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.5158 - loss: 1.3789 - val_accuracy: 0.5079 - val_loss: 1.3890
# Epoch 33/50
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.5227 - loss: 1.3662 - val_accuracy: 0.5170 - val_loss: 1.3733
# Epoch 34/50
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.5260 - loss: 1.3497 - val_accuracy: 0.5179 - val_loss: 1.3690
# Epoch 35/50
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.5294 - loss: 1.3461 - val_accuracy: 0.5176 - val_loss: 1.3764
# Epoch 36/50
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.5339 - loss: 1.3381 - val_accuracy: 0.5110 - val_loss: 1.3907
# Epoch 37/50
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.5346 - loss: 1.3283 - val_accuracy: 0.5231 - val_loss: 1.3485
# Epoch 38/50
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.5413 - loss: 1.3152 - val_accuracy: 0.5268 - val_loss: 1.3428
# Epoch 39/50
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.5364 - loss: 1.3210 - val_accuracy: 0.5149 - val_loss: 1.3716
# Epoch 40/50
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.5429 - loss: 1.3106 - val_accuracy: 0.5280 - val_loss: 1.3468
# Epoch 41/50
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.5443 - loss: 1.2994 - val_accuracy: 0.5391 - val_loss: 1.3201
# Epoch 42/50
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.5504 - loss: 1.2865 - val_accuracy: 0.5369 - val_loss: 1.3300
# Epoch 43/50
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.5538 - loss: 1.2735 - val_accuracy: 0.5488 - val_loss: 1.2996
# Epoch 44/50
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.5595 - loss: 1.2602 - val_accuracy: 0.5281 - val_loss: 1.3473
# Epoch 45/50
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.5557 - loss: 1.2741 - val_accuracy: 0.5214 - val_loss: 1.3712
# Epoch 46/50
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.5613 - loss: 1.2619 - val_accuracy: 0.5548 - val_loss: 1.2816
# Epoch 47/50
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.5699 - loss: 1.2379 - val_accuracy: 0.5465 - val_loss: 1.2929
# Epoch 48/50
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.5657 - loss: 1.2500 - val_accuracy: 0.5431 - val_loss: 1.2858
# Epoch 49/50
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.5693 - loss: 1.2361 - val_accuracy: 0.5543 - val_loss: 1.2634
# Epoch 50/50
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.5680 - loss: 1.2359 - val_accuracy: 0.5582 - val_loss: 1.2679

# %% [markdown]
# *   Plot the cross entropy loss curve and the accuracy curve

# %%
# Your code here :
import matplotlib.pyplot as plt

# Train the model and store the history
history = model.fit(x_train, y_train, epochs=50, batch_size=512, validation_data=(x_test, y_test))

# Plot the training and validation loss
plt.figure(figsize=(12, 6))
plt.subplot(1, 2, 1)
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.title('Training and Validation Loss')
plt.legend()

# Plot the training and validation accuracy
plt.subplot(1, 2, 2)
plt.plot(history.history['accuracy'], label='Training Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.title('Training and Validation Accuracy')
plt.legend()

plt.show()
# Out:
# Epoch 1/50
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 2s 18ms/step - accuracy: 0.5757 - loss: 1.2240 - val_accuracy: 0.5330 - val_loss: 1.3072
# Epoch 2/50
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.5753 - loss: 1.2140 - val_accuracy: 0.5208 - val_loss: 1.3546
# Epoch 3/50
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.5746 - loss: 1.2164 - val_accuracy: 0.5598 - val_loss: 1.2544
# Epoch 4/50
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.5784 - loss: 1.2116 - val_accuracy: 0.5530 - val_loss: 1.2640
# Epoch 5/50
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.5836 - loss: 1.1961 - val_accuracy: 0.5617 - val_loss: 1.2431
# Epoch 6/50
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.5843 - loss: 1.1951 - val_accuracy: 0.5570 - val_loss: 1.2520
# Epoch 7/50
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.5848 - loss: 1.1921 - val_accuracy: 0.5654 - val_loss: 1.2329
# Epoch 8/50
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.5926 - loss: 1.1759 - val_accuracy: 0.5584 - val_loss: 1.2472
# Epoch 9/50
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.5891 - loss: 1.1896 - val_accuracy: 0.5638 - val_loss: 1.2373
# Epoch 10/50
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.5983 - loss: 1.1638 - val_accuracy: 0.5721 - val_loss: 1.2214
# Epoch 11/50
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.5965 - loss: 1.1608 - val_accuracy: 0.5642 - val_loss: 1.2295
# Epoch 12/50
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.5935 - loss: 1.1658 - val_accuracy: 0.5652 - val_loss: 1.2295
# Epoch 13/50
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.5967 - loss: 1.1605 - val_accuracy: 0.5629 - val_loss: 1.2341
# Epoch 14/50
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.5952 - loss: 1.1604 - val_accuracy: 0.5627 - val_loss: 1.2325
# Epoch 15/50
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.6021 - loss: 1.1537 - val_accuracy: 0.5749 - val_loss: 1.2037
# Epoch 16/50
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.6006 - loss: 1.1495 - val_accuracy: 0.5658 - val_loss: 1.2424
# Epoch 17/50
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.6045 - loss: 1.1412 - val_accuracy: 0.5665 - val_loss: 1.2243
# Epoch 18/50
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.6031 - loss: 1.1372 - val_accuracy: 0.5617 - val_loss: 1.2585
# Epoch 19/50
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.5997 - loss: 1.1455 - val_accuracy: 0.5786 - val_loss: 1.1917
# Epoch 20/50
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.6144 - loss: 1.1208 - val_accuracy: 0.5817 - val_loss: 1.1896
# Epoch 21/50
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.6093 - loss: 1.1249 - val_accuracy: 0.5670 - val_loss: 1.2139
# Epoch 22/50
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.6087 - loss: 1.1227 - val_accuracy: 0.5765 - val_loss: 1.1959
# Epoch 23/50
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.6151 - loss: 1.1082 - val_accuracy: 0.5820 - val_loss: 1.1827
# Epoch 24/50
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.6166 - loss: 1.1065 - val_accuracy: 0.5762 - val_loss: 1.1956
# Epoch 25/50
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.6167 - loss: 1.1099 - val_accuracy: 0.5626 - val_loss: 1.2331
# Epoch 26/50
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.6203 - loss: 1.0933 - val_accuracy: 0.5701 - val_loss: 1.2235
# Epoch 27/50
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.6203 - loss: 1.1016 - val_accuracy: 0.5809 - val_loss: 1.1851
# Epoch 28/50
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.6205 - loss: 1.0985 - val_accuracy: 0.5879 - val_loss: 1.1671
# Epoch 29/50
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.6229 - loss: 1.0978 - val_accuracy: 0.5861 - val_loss: 1.1869
# Epoch 30/50
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.6241 - loss: 1.0902 - val_accuracy: 0.5829 - val_loss: 1.1716
# Epoch 31/50
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.6257 - loss: 1.0902 - val_accuracy: 0.5817 - val_loss: 1.1872
# Epoch 32/50
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.6239 - loss: 1.0892 - val_accuracy: 0.5813 - val_loss: 1.1919
# Epoch 33/50
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - accuracy: 0.6278 - loss: 1.0760 - val_accuracy: 0.5877 - val_loss: 1.1722
# Epoch 34/50
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.6238 - loss: 1.0801 - val_accuracy: 0.5836 - val_loss: 1.1832
# Epoch 35/50
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.6340 - loss: 1.0615 - val_accuracy: 0.5873 - val_loss: 1.1717
# Epoch 36/50
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.6287 - loss: 1.0762 - val_accuracy: 0.5810 - val_loss: 1.1785
# Epoch 37/50
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.6302 - loss: 1.0743 - val_accuracy: 0.5847 - val_loss: 1.1683
# Epoch 38/50
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.6349 - loss: 1.0546 - val_accuracy: 0.5976 - val_loss: 1.1534
# Epoch 39/50
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.6376 - loss: 1.0491 - val_accuracy: 0.5967 - val_loss: 1.1464
# Epoch 40/50
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.6403 - loss: 1.0493 - val_accuracy: 0.5969 - val_loss: 1.1462
# Epoch 41/50
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.6373 - loss: 1.0422 - val_accuracy: 0.5915 - val_loss: 1.1512
# Epoch 42/50
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.6418 - loss: 1.0477 - val_accuracy: 0.5953 - val_loss: 1.1482
# Epoch 43/50
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.6405 - loss: 1.0464 - val_accuracy: 0.6017 - val_loss: 1.1427
# Epoch 44/50
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.6379 - loss: 1.0457 - val_accuracy: 0.5906 - val_loss: 1.1539
# Epoch 45/50
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.6422 - loss: 1.0322 - val_accuracy: 0.5977 - val_loss: 1.1520
# Epoch 46/50
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.6432 - loss: 1.0345 - val_accuracy: 0.5931 - val_loss: 1.1552
# Epoch 47/50
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.6438 - loss: 1.0315 - val_accuracy: 0.6027 - val_loss: 1.1292
# Epoch 48/50
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.6450 - loss: 1.0313 - val_accuracy: 0.6030 - val_loss: 1.1421
# Epoch 49/50
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.6498 - loss: 1.0180 - val_accuracy: 0.6036 - val_loss: 1.1307
# Epoch 50/50
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.6468 - loss: 1.0182 - val_accuracy: 0.5955 - val_loss: 1.1577

# %% [markdown]
# ## Defining Deeper Architectures: VGG Models
#
# *   Define a deeper model architecture for CIFAR-10 dataset and train the new model for 50 epochs with a batch size of 512. We will use VGG model as the architecture.
#
# Stack two convolutional layers with 32 filters, each of 3 x 3.
#
# Use a max pooling layer and next flatten the output of the previous layer and add a dense layer with 128 units before the classification layer.
#
# For all the layers, use ReLU activation function.
#
# Use same padding for the layers to ensure that the height and width of each layer output matches the input

# %%
from keras.backend import clear_session
clear_session()

# %%
# Your code here :
# Define the VGG model architecture
model = Sequential()

model.add(Conv2D(32, (3, 3), activation='relu', padding='same', input_shape=(32, 32, 3)))
model.add(Conv2D(32, (3, 3), activation='relu', padding='same'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Flatten())
model.add(Dense(128, activation='relu'))
model.add(Dense(10, activation='softmax'))

model.summary()

# Compile the model
model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])

# Train the model
model.fit(x_train, y_train, epochs=50, batch_size=512, validation_data=(x_test, y_test))
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ conv2d (Conv2D)                      │ (None, 32, 32, 32)          │             896 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_1 (Conv2D)                    │ (None, 32, 32, 32)          │           9,248 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d (MaxPooling2D)         │ (None, 16, 16, 32)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ flatten (Flatten)                    │ (None, 8192)                │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense (Dense)                        │ (None, 128)                 │       1,048,704 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_1 (Dense)                      │ (None, 10)                  │           1,290 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 1,060,138 (4.04 MB)
#  Trainable params: 1,060,138 (4.04 MB)
#  Non-trainable params: 0 (0.00 B)
# Epoch 1/50
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 6s 39ms/step - accuracy: 0.3159 - loss: 1.8978 - val_accuracy: 0.4976 - val_loss: 1.4209
# Epoch 2/50
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 2s 22ms/step - accuracy: 0.5271 - loss: 1.3448 - val_accuracy: 0.5699 - val_loss: 1.2180
# Epoch 3/50
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 22ms/step - accuracy: 0.6014 - loss: 1.1564 - val_accuracy: 0.6028 - val_loss: 1.1409
# Epoch 4/50
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 2s 22ms/step - accuracy: 0.6342 - loss: 1.0526 - val_accuracy: 0.6282 - val_loss: 1.0691
# Epoch 5/50
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 22ms/step - accuracy: 0.6665 - loss: 0.9586 - val_accuracy: 0.6480 - val_loss: 1.0046
# Epoch 6/50
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 2s 22ms/step - accuracy: 0.6881 - loss: 0.8980 - val_accuracy: 0.6538 - val_loss: 0.9819
# Epoch 7/50
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 22ms/step - accuracy: 0.7095 - loss: 0.8335 - val_accuracy: 0.6524 - val_loss: 0.9870
# Epoch 8/50
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 2s 22ms/step - accuracy: 0.7227 - loss: 0.7996 - val_accuracy: 0.6751 - val_loss: 0.9344
# Epoch 9/50
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 2s 23ms/step - accuracy: 0.7460 - loss: 0.7428 - val_accuracy: 0.6737 - val_loss: 0.9425
# Epoch 10/50
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 2s 23ms/step - accuracy: 0.7552 - loss: 0.7101 - val_accuracy: 0.6820 - val_loss: 0.9276
# Epoch 11/50
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 2s 22ms/step - accuracy: 0.7778 - loss: 0.6542 - val_accuracy: 0.6842 - val_loss: 0.9280
# Epoch 12/50
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 2s 22ms/step - accuracy: 0.7841 - loss: 0.6284 - val_accuracy: 0.6769 - val_loss: 0.9502
# Epoch 13/50
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 2s 22ms/step - accuracy: 0.7988 - loss: 0.5914 - val_accuracy: 0.6875 - val_loss: 0.9299
# Epoch 14/50
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 22ms/step - accuracy: 0.8113 - loss: 0.5546 - val_accuracy: 0.6906 - val_loss: 0.9318
# Epoch 15/50
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 22ms/step - accuracy: 0.8326 - loss: 0.4979 - val_accuracy: 0.6833 - val_loss: 0.9427
# Epoch 16/50
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 2s 22ms/step - accuracy: 0.8422 - loss: 0.4727 - val_accuracy: 0.6814 - val_loss: 0.9805
# Epoch 17/50
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 2s 22ms/step - accuracy: 0.8588 - loss: 0.4325 - val_accuracy: 0.6865 - val_loss: 0.9816
# Epoch 18/50
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 22ms/step - accuracy: 0.8678 - loss: 0.3996 - val_accuracy: 0.6806 - val_loss: 1.0373
# Epoch 19/50
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 2s 22ms/step - accuracy: 0.8782 - loss: 0.3712 - val_accuracy: 0.6808 - val_loss: 1.0504
# Epoch 20/50
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 23ms/step - accuracy: 0.9008 - loss: 0.3177 - val_accuracy: 0.6786 - val_loss: 1.0899
# Epoch 21/50
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 2s 22ms/step - accuracy: 0.9062 - loss: 0.2997 - val_accuracy: 0.6778 - val_loss: 1.1200
# Epoch 22/50
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 2s 22ms/step - accuracy: 0.9278 - loss: 0.2500 - val_accuracy: 0.6739 - val_loss: 1.1660
# Epoch 23/50
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 2s 22ms/step - accuracy: 0.9314 - loss: 0.2343 - val_accuracy: 0.6765 - val_loss: 1.2027
# Epoch 24/50
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 24ms/step - accuracy: 0.9456 - loss: 0.2011 - val_accuracy: 0.6708 - val_loss: 1.2884
# Epoch 25/50
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 2s 25ms/step - accuracy: 0.9542 - loss: 0.1713 - val_accuracy: 0.6776 - val_loss: 1.3039
# Epoch 26/50
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 2s 22ms/step - accuracy: 0.9609 - loss: 0.1541 - val_accuracy: 0.6686 - val_loss: 1.3695
# Epoch 27/50
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 2s 22ms/step - accuracy: 0.9675 - loss: 0.1323 - val_accuracy: 0.6674 - val_loss: 1.4476
# Epoch 28/50
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 22ms/step - accuracy: 0.9750 - loss: 0.1094 - val_accuracy: 0.6685 - val_loss: 1.4973
# Epoch 29/50
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 2s 22ms/step - accuracy: 0.9816 - loss: 0.0921 - val_accuracy: 0.6728 - val_loss: 1.5640
# Epoch 30/50
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 25ms/step - accuracy: 0.9873 - loss: 0.0730 - val_accuracy: 0.6715 - val_loss: 1.6219
# Epoch 31/50
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 2s 22ms/step - accuracy: 0.9898 - loss: 0.0621 - val_accuracy: 0.6699 - val_loss: 1.6961
# Epoch 32/50
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 2s 24ms/step - accuracy: 0.9910 - loss: 0.0568 - val_accuracy: 0.6716 - val_loss: 1.7339
# Epoch 33/50
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 2s 22ms/step - accuracy: 0.9951 - loss: 0.0416 - val_accuracy: 0.6669 - val_loss: 1.8278
# Epoch 34/50
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 2s 22ms/step - accuracy: 0.9963 - loss: 0.0339 - val_accuracy: 0.6686 - val_loss: 1.9087
# Epoch 35/50
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 2s 23ms/step - accuracy: 0.9982 - loss: 0.0265 - val_accuracy: 0.6704 - val_loss: 1.9564
# Epoch 36/50
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 2s 22ms/step - accuracy: 0.9991 - loss: 0.0200 - val_accuracy: 0.6695 - val_loss: 2.0156
# Epoch 37/50
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 2s 22ms/step - accuracy: 0.9996 - loss: 0.0170 - val_accuracy: 0.6682 - val_loss: 2.0709
# Epoch 38/50
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 24ms/step - accuracy: 0.9996 - loss: 0.0139 - val_accuracy: 0.6684 - val_loss: 2.1328
# Epoch 39/50
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 2s 22ms/step - accuracy: 0.9997 - loss: 0.0109 - val_accuracy: 0.6690 - val_loss: 2.1834
# Epoch 40/50
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 25ms/step - accuracy: 0.9998 - loss: 0.0087 - val_accuracy: 0.6699 - val_loss: 2.2215
# Epoch 41/50
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 2s 22ms/step - accuracy: 0.9998 - loss: 0.0071 - val_accuracy: 0.6686 - val_loss: 2.2743
# Epoch 42/50
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 2s 22ms/step - accuracy: 0.9999 - loss: 0.0061 - val_accuracy: 0.6685 - val_loss: 2.3197
# Epoch 43/50
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 2s 22ms/step - accuracy: 0.9999 - loss: 0.0049 - val_accuracy: 0.6675 - val_loss: 2.3617
# Epoch 44/50
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 22ms/step - accuracy: 0.9998 - loss: 0.0048 - val_accuracy: 0.6691 - val_loss: 2.4028
# Epoch 45/50
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 2s 24ms/step - accuracy: 1.0000 - loss: 0.0040 - val_accuracy: 0.6692 - val_loss: 2.4541
# Epoch 46/50
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 2s 22ms/step - accuracy: 1.0000 - loss: 0.0033 - val_accuracy: 0.6687 - val_loss: 2.4685
# Epoch 47/50
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 2s 22ms/step - accuracy: 1.0000 - loss: 0.0030 - val_accuracy: 0.6695 - val_loss: 2.5184
# Epoch 48/50
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 2s 22ms/step - accuracy: 0.9999 - loss: 0.0032 - val_accuracy: 0.6694 - val_loss: 2.5444
# Epoch 49/50
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 22ms/step - accuracy: 1.0000 - loss: 0.0024 - val_accuracy: 0.6663 - val_loss: 2.5965
# Epoch 50/50
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 24ms/step - accuracy: 1.0000 - loss: 0.0024 - val_accuracy: 0.6692 - val_loss: 2.6109

# %% [markdown]
# *   Compile the model using categorical_crossentropy loss, SGD optimizer and use 'accuracy' as the metric.
# *   Use the above defined model to train CIFAR-10 and train the model for 50 epochs with a batch size of 512.

# %%
# Your code here :
# Compile the model
model.compile(loss='categorical_crossentropy', optimizer=SGD(), metrics=['accuracy'])

# Train the model
model.fit(x_train, y_train, epochs=50, batch_size=512, validation_data=(x_test, y_test))
# Out:
# Epoch 1/50
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 4s 37ms/step - accuracy: 1.0000 - loss: 0.0020 - val_accuracy: 0.6694 - val_loss: 2.6124
# Epoch 2/50
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 2s 22ms/step - accuracy: 1.0000 - loss: 0.0018 - val_accuracy: 0.6693 - val_loss: 2.6192
# Epoch 3/50
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 2s 24ms/step - accuracy: 1.0000 - loss: 0.0018 - val_accuracy: 0.6701 - val_loss: 2.6240
# Epoch 4/50
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 2s 22ms/step - accuracy: 1.0000 - loss: 0.0018 - val_accuracy: 0.6693 - val_loss: 2.6303
# Epoch 5/50
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 2s 22ms/step - accuracy: 1.0000 - loss: 0.0018 - val_accuracy: 0.6695 - val_loss: 2.6359
# Epoch 6/50
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 2s 22ms/step - accuracy: 1.0000 - loss: 0.0017 - val_accuracy: 0.6693 - val_loss: 2.6407
# Epoch 7/50
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 22ms/step - accuracy: 1.0000 - loss: 0.0017 - val_accuracy: 0.6687 - val_loss: 2.6452
# Epoch 8/50
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 22ms/step - accuracy: 1.0000 - loss: 0.0017 - val_accuracy: 0.6689 - val_loss: 2.6496
# Epoch 9/50
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 2s 22ms/step - accuracy: 1.0000 - loss: 0.0017 - val_accuracy: 0.6691 - val_loss: 2.6538
# Epoch 10/50
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 2s 22ms/step - accuracy: 1.0000 - loss: 0.0017 - val_accuracy: 0.6686 - val_loss: 2.6580
# Epoch 11/50
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 2s 22ms/step - accuracy: 1.0000 - loss: 0.0017 - val_accuracy: 0.6689 - val_loss: 2.6624
# Epoch 12/50
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 2s 22ms/step - accuracy: 1.0000 - loss: 0.0017 - val_accuracy: 0.6687 - val_loss: 2.6663
# Epoch 13/50
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 2s 22ms/step - accuracy: 1.0000 - loss: 0.0016 - val_accuracy: 0.6688 - val_loss: 2.6719
# Epoch 14/50
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 25ms/step - accuracy: 1.0000 - loss: 0.0016 - val_accuracy: 0.6686 - val_loss: 2.6776
# Epoch 15/50
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 2s 22ms/step - accuracy: 1.0000 - loss: 0.0016 - val_accuracy: 0.6681 - val_loss: 2.6789
# Epoch 16/50
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 2s 22ms/step - accuracy: 1.0000 - loss: 0.0016 - val_accuracy: 0.6680 - val_loss: 2.6843
# Epoch 17/50
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 22ms/step - accuracy: 1.0000 - loss: 0.0016 - val_accuracy: 0.6688 - val_loss: 2.6875
# Epoch 18/50
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 22ms/step - accuracy: 1.0000 - loss: 0.0016 - val_accuracy: 0.6686 - val_loss: 2.6906
# Epoch 19/50
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 24ms/step - accuracy: 1.0000 - loss: 0.0015 - val_accuracy: 0.6696 - val_loss: 2.6941
# Epoch 20/50
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 2s 22ms/step - accuracy: 1.0000 - loss: 0.0016 - val_accuracy: 0.6683 - val_loss: 2.6997
# Epoch 21/50
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 24ms/step - accuracy: 1.0000 - loss: 0.0015 - val_accuracy: 0.6688 - val_loss: 2.7016
# Epoch 22/50
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 2s 22ms/step - accuracy: 1.0000 - loss: 0.0015 - val_accuracy: 0.6682 - val_loss: 2.7053
# Epoch 23/50
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 22ms/step - accuracy: 1.0000 - loss: 0.0015 - val_accuracy: 0.6691 - val_loss: 2.7098
# Epoch 24/50
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 2s 23ms/step - accuracy: 1.0000 - loss: 0.0015 - val_accuracy: 0.6677 - val_loss: 2.7135
# Epoch 25/50
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 2s 22ms/step - accuracy: 1.0000 - loss: 0.0015 - val_accuracy: 0.6682 - val_loss: 2.7170
# Epoch 26/50
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 22ms/step - accuracy: 1.0000 - loss: 0.0015 - val_accuracy: 0.6677 - val_loss: 2.7203
# Epoch 27/50
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 2s 22ms/step - accuracy: 1.0000 - loss: 0.0015 - val_accuracy: 0.6683 - val_loss: 2.7240
# Epoch 28/50
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 22ms/step - accuracy: 1.0000 - loss: 0.0014 - val_accuracy: 0.6681 - val_loss: 2.7286
# Epoch 29/50
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 2s 24ms/step - accuracy: 1.0000 - loss: 0.0014 - val_accuracy: 0.6683 - val_loss: 2.7297
# Epoch 30/50
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 2s 22ms/step - accuracy: 1.0000 - loss: 0.0015 - val_accuracy: 0.6685 - val_loss: 2.7347
# Epoch 31/50
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 22ms/step - accuracy: 1.0000 - loss: 0.0014 - val_accuracy: 0.6680 - val_loss: 2.7366
# Epoch 32/50
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 2s 22ms/step - accuracy: 1.0000 - loss: 0.0014 - val_accuracy: 0.6680 - val_loss: 2.7404
# Epoch 33/50
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 2s 22ms/step - accuracy: 1.0000 - loss: 0.0014 - val_accuracy: 0.6682 - val_loss: 2.7440
# Epoch 34/50
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 24ms/step - accuracy: 1.0000 - loss: 0.0014 - val_accuracy: 0.6685 - val_loss: 2.7465
# Epoch 35/50
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 2s 22ms/step - accuracy: 1.0000 - loss: 0.0014 - val_accuracy: 0.6683 - val_loss: 2.7500
# Epoch 36/50
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 2s 22ms/step - accuracy: 1.0000 - loss: 0.0014 - val_accuracy: 0.6675 - val_loss: 2.7534
# Epoch 37/50
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 24ms/step - accuracy: 1.0000 - loss: 0.0014 - val_accuracy: 0.6681 - val_loss: 2.7549
# Epoch 38/50
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 2s 22ms/step - accuracy: 1.0000 - loss: 0.0013 - val_accuracy: 0.6686 - val_loss: 2.7601
# Epoch 39/50
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 2s 24ms/step - accuracy: 1.0000 - loss: 0.0013 - val_accuracy: 0.6679 - val_loss: 2.7611
# Epoch 40/50
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 2s 22ms/step - accuracy: 1.0000 - loss: 0.0013 - val_accuracy: 0.6688 - val_loss: 2.7661
# Epoch 41/50
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 22ms/step - accuracy: 1.0000 - loss: 0.0013 - val_accuracy: 0.6684 - val_loss: 2.7692
# Epoch 42/50
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 2s 24ms/step - accuracy: 1.0000 - loss: 0.0013 - val_accuracy: 0.6683 - val_loss: 2.7701
# Epoch 43/50
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 2s 22ms/step - accuracy: 1.0000 - loss: 0.0013 - val_accuracy: 0.6683 - val_loss: 2.7734
# Epoch 44/50
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 2s 24ms/step - accuracy: 1.0000 - loss: 0.0013 - val_accuracy: 0.6690 - val_loss: 2.7768
# Epoch 45/50
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 2s 22ms/step - accuracy: 1.0000 - loss: 0.0013 - val_accuracy: 0.6683 - val_loss: 2.7796
# Epoch 46/50
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 2s 22ms/step - accuracy: 1.0000 - loss: 0.0013 - val_accuracy: 0.6686 - val_loss: 2.7808
# Epoch 47/50
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 22ms/step - accuracy: 1.0000 - loss: 0.0013 - val_accuracy: 0.6685 - val_loss: 2.7862
# Epoch 48/50
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 22ms/step - accuracy: 1.0000 - loss: 0.0013 - val_accuracy: 0.6684 - val_loss: 2.7872
# Epoch 49/50
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 2s 24ms/step - accuracy: 1.0000 - loss: 0.0013 - val_accuracy: 0.6684 - val_loss: 2.7901
# Epoch 50/50
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 2s 22ms/step - accuracy: 1.0000 - loss: 0.0013 - val_accuracy: 0.6688 - val_loss: 2.7944

# %% [markdown]
# *   Compare the performance of both the models by plotting the loss and accuracy curves of both the training steps. Does the deeper model perform better? Comment on the observation.

# %%
# Your code here :

# Define and train the CNN model
cnn_model = Sequential()
cnn_model.add(Conv2D(32, (3, 3), activation='relu', input_shape=(32, 32, 3)))
cnn_model.add(MaxPooling2D(pool_size=(2, 2)))
cnn_model.add(Flatten())
cnn_model.add(Dense(100, activation='relu'))
cnn_model.add(Dense(10, activation='softmax'))
cnn_model.compile(loss='categorical_crossentropy', optimizer='sgd', metrics=['accuracy'])
cnn_history = cnn_model.fit(x_train, y_train, epochs=50, batch_size=512, validation_data=(x_test, y_test))

# Define and train the VGG model
vgg_model = Sequential()
vgg_model.add(Conv2D(32, (3, 3), activation='relu', padding='same', input_shape=(32, 32, 3)))
vgg_model.add(Conv2D(32, (3, 3), activation='relu', padding='same'))
vgg_model.add(MaxPooling2D(pool_size=(2, 2)))
vgg_model.add(Flatten())
vgg_model.add(Dense(128, activation='relu'))
vgg_model.add(Dense(10, activation='softmax'))
vgg_model.compile(loss='categorical_crossentropy', optimizer='sgd', metrics=['accuracy'])
vgg_history = vgg_model.fit(x_train, y_train, epochs=50, batch_size=512, validation_data=(x_test, y_test))

# Plot the training and validation loss for both models
plt.figure(figsize=(12, 6))
plt.subplot(1, 2, 1)
plt.plot(cnn_history.history['loss'], label='CNN Training Loss')
plt.plot(cnn_history.history['val_loss'], label='CNN Validation Loss')
plt.plot(vgg_history.history['loss'], label='VGG Training Loss')
plt.plot(vgg_history.history['val_loss'], label='VGG Validation Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.title('Training and Validation Loss')
plt.legend()

# Plot the training and validation accuracy for both models
plt.subplot(1, 2, 2)
plt.plot(cnn_history.history['accuracy'], label='CNN Training Accuracy')
plt.plot(cnn_history.history['val_accuracy'], label='CNN Validation Accuracy')
plt.plot(vgg_history.history['accuracy'], label='VGG Training Accuracy')
plt.plot(vgg_history.history['val_accuracy'], label='VGG Validation Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.title('Training and Validation Accuracy')
plt.legend()

plt.show()
# Out:
# Epoch 1/50
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 25ms/step - accuracy: 0.1451 - loss: 2.2849 - val_accuracy: 0.2540 - val_loss: 2.1989
# Epoch 2/50
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 11ms/step - accuracy: 0.2561 - loss: 2.1669 - val_accuracy: 0.3042 - val_loss: 2.0608
# Epoch 3/50
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.3034 - loss: 2.0334 - val_accuracy: 0.3061 - val_loss: 1.9568
# Epoch 4/50
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.3225 - loss: 1.9450 - val_accuracy: 0.3248 - val_loss: 1.9105
# Epoch 5/50
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.3396 - loss: 1.8969 - val_accuracy: 0.3608 - val_loss: 1.8610
# Epoch 6/50
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.3545 - loss: 1.8556 - val_accuracy: 0.3533 - val_loss: 1.8554
# Epoch 7/50
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.3670 - loss: 1.8282 - val_accuracy: 0.3716 - val_loss: 1.8120
# Epoch 8/50
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.3832 - loss: 1.7946 - val_accuracy: 0.3876 - val_loss: 1.7778
# Epoch 9/50
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.3878 - loss: 1.7732 - val_accuracy: 0.3875 - val_loss: 1.7639
# Epoch 10/50
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.3856 - loss: 1.7585 - val_accuracy: 0.3962 - val_loss: 1.7410
# Epoch 11/50
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.4020 - loss: 1.7265 - val_accuracy: 0.4075 - val_loss: 1.7167
# Epoch 12/50
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.4125 - loss: 1.6993 - val_accuracy: 0.4169 - val_loss: 1.6881
# Epoch 13/50
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.4192 - loss: 1.6826 - val_accuracy: 0.4097 - val_loss: 1.6989
# Epoch 14/50
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.4209 - loss: 1.6697 - val_accuracy: 0.4248 - val_loss: 1.6495
# Epoch 15/50
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.4241 - loss: 1.6565 - val_accuracy: 0.4168 - val_loss: 1.6656
# Epoch 16/50
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.4342 - loss: 1.6272 - val_accuracy: 0.4403 - val_loss: 1.6038
# Epoch 17/50
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.4442 - loss: 1.6060 - val_accuracy: 0.4299 - val_loss: 1.6185
# Epoch 18/50
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.4429 - loss: 1.5957 - val_accuracy: 0.4475 - val_loss: 1.5757
# Epoch 19/50
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.4528 - loss: 1.5671 - val_accuracy: 0.4527 - val_loss: 1.5527
# Epoch 20/50
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.4596 - loss: 1.5416 - val_accuracy: 0.4624 - val_loss: 1.5319
# Epoch 21/50
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.4654 - loss: 1.5305 - val_accuracy: 0.4692 - val_loss: 1.5152
# Epoch 22/50
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.4750 - loss: 1.5022 - val_accuracy: 0.4665 - val_loss: 1.5105
# Epoch 23/50
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.4754 - loss: 1.4956 - val_accuracy: 0.4675 - val_loss: 1.5022
# Epoch 24/50
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.4809 - loss: 1.4847 - val_accuracy: 0.4854 - val_loss: 1.4622
# Epoch 25/50
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.4921 - loss: 1.4566 - val_accuracy: 0.4854 - val_loss: 1.4566
# Epoch 26/50
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.4926 - loss: 1.4446 - val_accuracy: 0.4880 - val_loss: 1.4393
# Epoch 27/50
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.5079 - loss: 1.4146 - val_accuracy: 0.4696 - val_loss: 1.4806
# Epoch 28/50
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.5027 - loss: 1.4119 - val_accuracy: 0.4892 - val_loss: 1.4294
# Epoch 29/50
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.5066 - loss: 1.4040 - val_accuracy: 0.4949 - val_loss: 1.4203
# Epoch 30/50
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.5105 - loss: 1.3906 - val_accuracy: 0.5028 - val_loss: 1.4113
# Epoch 31/50
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.5129 - loss: 1.3791 - val_accuracy: 0.4990 - val_loss: 1.4069
# Epoch 32/50
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.5237 - loss: 1.3554 - val_accuracy: 0.5157 - val_loss: 1.3651
# Epoch 33/50
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.5241 - loss: 1.3557 - val_accuracy: 0.5195 - val_loss: 1.3578
# Epoch 34/50
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.5193 - loss: 1.3628 - val_accuracy: 0.5148 - val_loss: 1.3565
# Epoch 35/50
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.5277 - loss: 1.3450 - val_accuracy: 0.4889 - val_loss: 1.4208
# Epoch 36/50
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.5336 - loss: 1.3271 - val_accuracy: 0.5244 - val_loss: 1.3376
# Epoch 37/50
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.5372 - loss: 1.3109 - val_accuracy: 0.5217 - val_loss: 1.3407
# Epoch 38/50
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.5361 - loss: 1.3081 - val_accuracy: 0.5176 - val_loss: 1.3579
# Epoch 39/50
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.5413 - loss: 1.3027 - val_accuracy: 0.5085 - val_loss: 1.3733
# Epoch 40/50
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.5465 - loss: 1.2931 - val_accuracy: 0.5383 - val_loss: 1.3010
# Epoch 41/50
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.5495 - loss: 1.2787 - val_accuracy: 0.5388 - val_loss: 1.3031
# Epoch 42/50
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.5580 - loss: 1.2700 - val_accuracy: 0.5472 - val_loss: 1.2816
# Epoch 43/50
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.5550 - loss: 1.2655 - val_accuracy: 0.5423 - val_loss: 1.2796
# Epoch 44/50
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.5627 - loss: 1.2441 - val_accuracy: 0.5486 - val_loss: 1.2844
# Epoch 45/50
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.5624 - loss: 1.2585 - val_accuracy: 0.5459 - val_loss: 1.2852
# Epoch 46/50
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.5642 - loss: 1.2421 - val_accuracy: 0.5371 - val_loss: 1.3073
# Epoch 47/50
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.5677 - loss: 1.2390 - val_accuracy: 0.5527 - val_loss: 1.2472
# Epoch 48/50
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.5638 - loss: 1.2334 - val_accuracy: 0.5558 - val_loss: 1.2447
# Epoch 49/50
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.5739 - loss: 1.2179 - val_accuracy: 0.5566 - val_loss: 1.2467
# Epoch 50/50
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.5739 - loss: 1.2175 - val_accuracy: 0.5557 - val_loss: 1.2495
# Epoch 1/50
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 6s 47ms/step - accuracy: 0.1409 - loss: 2.2822 - val_accuracy: 0.2469 - val_loss: 2.1971
# Epoch 2/50
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 2s 23ms/step - accuracy: 0.2474 - loss: 2.1432 - val_accuracy: 0.2966 - val_loss: 1.9938
# Epoch 3/50
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 2s 22ms/step - accuracy: 0.2920 - loss: 1.9870 - val_accuracy: 0.3204 - val_loss: 1.9246
# Epoch 4/50
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 2s 22ms/step - accuracy: 0.3187 - loss: 1.9247 - val_accuracy: 0.3295 - val_loss: 1.8734
# Epoch 5/50
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 22ms/step - accuracy: 0.3445 - loss: 1.8663 - val_accuracy: 0.3532 - val_loss: 1.8234
# Epoch 6/50
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 22ms/step - accuracy: 0.3658 - loss: 1.8130 - val_accuracy: 0.3761 - val_loss: 1.7764
# Epoch 7/50
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 22ms/step - accuracy: 0.3805 - loss: 1.7773 - val_accuracy: 0.3936 - val_loss: 1.7320
# Epoch 8/50
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 22ms/step - accuracy: 0.3967 - loss: 1.7339 - val_accuracy: 0.3739 - val_loss: 1.7460
# Epoch 9/50
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 2s 22ms/step - accuracy: 0.3993 - loss: 1.7149 - val_accuracy: 0.3971 - val_loss: 1.6945
# Epoch 10/50
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 24ms/step - accuracy: 0.4095 - loss: 1.6740 - val_accuracy: 0.4141 - val_loss: 1.6613
# Epoch 11/50
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 2s 22ms/step - accuracy: 0.4184 - loss: 1.6526 - val_accuracy: 0.4097 - val_loss: 1.6677
# Epoch 12/50
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 22ms/step - accuracy: 0.4265 - loss: 1.6347 - val_accuracy: 0.4208 - val_loss: 1.6323
# Epoch 13/50
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 2s 22ms/step - accuracy: 0.4375 - loss: 1.6038 - val_accuracy: 0.4038 - val_loss: 1.6589
# Epoch 14/50
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 22ms/step - accuracy: 0.4460 - loss: 1.5757 - val_accuracy: 0.4271 - val_loss: 1.6146
# Epoch 15/50
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 22ms/step - accuracy: 0.4505 - loss: 1.5646 - val_accuracy: 0.4531 - val_loss: 1.5565
# Epoch 16/50
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 2s 22ms/step - accuracy: 0.4610 - loss: 1.5316 - val_accuracy: 0.4562 - val_loss: 1.5499
# Epoch 17/50
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 2s 22ms/step - accuracy: 0.4697 - loss: 1.5141 - val_accuracy: 0.4714 - val_loss: 1.4890
# Epoch 18/50
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 2s 22ms/step - accuracy: 0.4762 - loss: 1.5018 - val_accuracy: 0.4761 - val_loss: 1.4835
# Epoch 19/50
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 22ms/step - accuracy: 0.4811 - loss: 1.4685 - val_accuracy: 0.4652 - val_loss: 1.5376
# Epoch 20/50
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 24ms/step - accuracy: 0.4828 - loss: 1.4716 - val_accuracy: 0.4873 - val_loss: 1.4515
# Epoch 21/50
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 2s 22ms/step - accuracy: 0.4936 - loss: 1.4385 - val_accuracy: 0.4794 - val_loss: 1.4494
# Epoch 22/50
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 22ms/step - accuracy: 0.4932 - loss: 1.4344 - val_accuracy: 0.4885 - val_loss: 1.4347
# Epoch 23/50
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 2s 22ms/step - accuracy: 0.4969 - loss: 1.4200 - val_accuracy: 0.4990 - val_loss: 1.4033
# Epoch 24/50
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 22ms/step - accuracy: 0.5093 - loss: 1.3919 - val_accuracy: 0.4923 - val_loss: 1.4231
# Epoch 25/50
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 24ms/step - accuracy: 0.5166 - loss: 1.3767 - val_accuracy: 0.4868 - val_loss: 1.4230
# Epoch 26/50
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 2s 22ms/step - accuracy: 0.5160 - loss: 1.3757 - val_accuracy: 0.5039 - val_loss: 1.4046
# Epoch 27/50
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 2s 22ms/step - accuracy: 0.5143 - loss: 1.3751 - val_accuracy: 0.5166 - val_loss: 1.3783
# Epoch 28/50
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 22ms/step - accuracy: 0.5230 - loss: 1.3460 - val_accuracy: 0.5211 - val_loss: 1.3499
# Epoch 29/50
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 22ms/step - accuracy: 0.5304 - loss: 1.3404 - val_accuracy: 0.5230 - val_loss: 1.3410
# Epoch 30/50
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 2s 22ms/step - accuracy: 0.5341 - loss: 1.3251 - val_accuracy: 0.5193 - val_loss: 1.3428
# Epoch 31/50
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 22ms/step - accuracy: 0.5411 - loss: 1.3138 - val_accuracy: 0.5247 - val_loss: 1.3507
# Epoch 32/50
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 22ms/step - accuracy: 0.5459 - loss: 1.2972 - val_accuracy: 0.5301 - val_loss: 1.3281
# Epoch 33/50
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 22ms/step - accuracy: 0.5421 - loss: 1.2977 - val_accuracy: 0.5312 - val_loss: 1.3298
# Epoch 34/50
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 2s 24ms/step - accuracy: 0.5531 - loss: 1.2785 - val_accuracy: 0.5233 - val_loss: 1.3334
# Epoch 35/50
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 2s 24ms/step - accuracy: 0.5519 - loss: 1.2724 - val_accuracy: 0.5292 - val_loss: 1.3128
# Epoch 36/50
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 2s 22ms/step - accuracy: 0.5577 - loss: 1.2632 - val_accuracy: 0.5381 - val_loss: 1.3084
# Epoch 37/50
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 22ms/step - accuracy: 0.5602 - loss: 1.2593 - val_accuracy: 0.5252 - val_loss: 1.3485
# Epoch 38/50
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 2s 22ms/step - accuracy: 0.5654 - loss: 1.2388 - val_accuracy: 0.5317 - val_loss: 1.3175
# Epoch 39/50
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 2s 22ms/step - accuracy: 0.5723 - loss: 1.2233 - val_accuracy: 0.5500 - val_loss: 1.2743
# Epoch 40/50
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 2s 23ms/step - accuracy: 0.5745 - loss: 1.2172 - val_accuracy: 0.5378 - val_loss: 1.2909
# Epoch 41/50
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 2s 22ms/step - accuracy: 0.5736 - loss: 1.2199 - val_accuracy: 0.5458 - val_loss: 1.3077
# Epoch 42/50
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 22ms/step - accuracy: 0.5778 - loss: 1.2064 - val_accuracy: 0.5537 - val_loss: 1.2696
# Epoch 43/50
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 2s 22ms/step - accuracy: 0.5855 - loss: 1.1892 - val_accuracy: 0.5608 - val_loss: 1.2372
# Epoch 44/50
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 22ms/step - accuracy: 0.5868 - loss: 1.1840 - val_accuracy: 0.5461 - val_loss: 1.2691
# Epoch 45/50
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 2s 24ms/step - accuracy: 0.5895 - loss: 1.1733 - val_accuracy: 0.5688 - val_loss: 1.2285
# Epoch 46/50
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 2s 22ms/step - accuracy: 0.5909 - loss: 1.1676 - val_accuracy: 0.5659 - val_loss: 1.2207
# Epoch 47/50
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 2s 22ms/step - accuracy: 0.5948 - loss: 1.1610 - val_accuracy: 0.5713 - val_loss: 1.2121
# Epoch 48/50
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 22ms/step - accuracy: 0.6056 - loss: 1.1364 - val_accuracy: 0.5745 - val_loss: 1.2020
# Epoch 49/50
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 2s 22ms/step - accuracy: 0.5986 - loss: 1.1555 - val_accuracy: 0.5744 - val_loss: 1.1994
# Epoch 50/50
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 2s 22ms/step - accuracy: 0.6054 - loss: 1.1289 - val_accuracy: 0.5483 - val_loss: 1.2832

# %% [markdown]
# **Comment on the observation**
#
# *(Double-click or enter to edit)*
#
# ...

# %% [markdown]
# *   Use predict function to predict the output for the test split
# *   Plot the confusion matrix for the new model and comment on the class confusions.

# %%
# Your code here :
from sklearn.metrics import confusion_matrix
import seaborn as sns

# Predict the output for the test split using the VGG model
y_pred = vgg_model.predict(x_test)

# Get the class labels of the predictions
y_pred_labels = np.argmax(y_pred, axis=1)
y_true_labels = np.argmax(y_test, axis=1)

# Create the confusion matrix
conf_matrix = confusion_matrix(y_true_labels, y_pred_labels)

# Plot the confusion matrix
plt.figure(figsize=(10, 8))
sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='Blues', xticklabels=range(10), yticklabels=range(10))
plt.xlabel('Predicted labels')
plt.ylabel('True labels')
plt.title('Confusion Matrix')
plt.show()
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step

# %% [markdown]
# **Comment here :**
#
# *(Double-click or enter to edit)*
#
# ...

# %% [markdown]
# *    Print the test accuracy for the trained model.

# %%
# Your code here :
# Evaluate the model on the test data
test_loss, test_accuracy = vgg_model.evaluate(x_test, y_test)

print(f'Test Accuracy: {test_accuracy}')
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.5531 - loss: 1.2787
# Test Accuracy: 0.54830002784729

# %% [markdown]
# ## Define the complete VGG architecture.
#
# Stack two convolutional layers with 64 filters, each of 3 x 3 followed by max pooling layer.
#
# Stack two more convolutional layers with 128 filters, each of 3 x 3, followed by max pooling, followed by two more convolutional layers with 256 filters, each of 3 x 3, followed by max pooling.
#
# Flatten the output of the previous layer and add a dense layer with 128 units before the classification layer.
#
# For all the layers, use ReLU activation function.
#
# Use same padding for the layers to ensure that the height and width of each layer output matches the input
#
# *   Change the size of input to 64 x 64.

# %%
from keras.backend import clear_session
clear_session()

# %%
# Your code here :
# Define the VGG model architecture
model = Sequential()

model.add(Conv2D(64, (3, 3), activation='relu', padding='same', input_shape=(64, 64, 3)))
model.add(Conv2D(64, (3, 3), activation='relu', padding='same'))
model.add(MaxPooling2D(pool_size=(2, 2)))

model.add(Conv2D(128, (3, 3), activation='relu', padding='same'))
model.add(Conv2D(128, (3, 3), activation='relu', padding='same'))
model.add(MaxPooling2D(pool_size=(2, 2)))

model.add(Conv2D(256, (3, 3), activation='relu', padding='same'))
model.add(Conv2D(256, (3, 3), activation='relu', padding='same'))
model.add(MaxPooling2D(pool_size=(2, 2)))

model.add(Flatten())
model.add(Dense(128, activation='relu'))
model.add(Dense(10, activation='softmax'))

model.summary()
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/convolutional/base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ conv2d (Conv2D)                      │ (None, 64, 64, 64)          │           1,792 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_1 (Conv2D)                    │ (None, 64, 64, 64)          │          36,928 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d (MaxPooling2D)         │ (None, 32, 32, 64)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_2 (Conv2D)                    │ (None, 32, 32, 128)         │          73,856 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_3 (Conv2D)                    │ (None, 32, 32, 128)         │         147,584 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_1 (MaxPooling2D)       │ (None, 16, 16, 128)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_4 (Conv2D)                    │ (None, 16, 16, 256)         │         295,168 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_5 (Conv2D)                    │ (None, 16, 16, 256)         │         590,080 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_2 (MaxPooling2D)       │ (None, 8, 8, 256)           │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ flatten (Flatten)                    │ (None, 16384)               │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense (Dense)                        │ (None, 128)                 │       2,097,280 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_1 (Dense)                      │ (None, 10)                  │           1,290 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 3,243,978 (12.37 MB)
#  Trainable params: 3,243,978 (12.37 MB)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# *   Compile the model using categorical_crossentropy loss, SGD optimizer and use 'accuracy' as the metric.
# *   Use the above defined model to train CIFAR-10 and train the model for 10 epochs with a batch size of 512.
# *   Predict the output for the test split and plot the confusion matrix for the new model and comment on the class confusions.

# %%
# Your code here :
from keras.backend import clear_session
from tensorflow.image import resize
from tensorflow.keras.optimizers import SGD
import numpy as np

# Clear TensorFlow session
clear_session()

# Resize CIFAR-10 images to 64x64
x_train_resized = np.array([resize(image, (64, 64)).numpy() for image in x_train])
x_test_resized = np.array([resize(image, (64, 64)).numpy() for image in x_test])

# Normalize the resized images
x_train_resized = x_train_resized / 255.0
x_test_resized = x_test_resized / 255.0

# Re-compile the model
model.compile(optimizer=SGD(learning_rate=0.01, momentum=0.9),
              loss='categorical_crossentropy',
              metrics=['accuracy'])

# Train the model
history = model.fit(
    x_train_resized, y_train,
    validation_data=(x_test_resized, y_test),
    epochs=10,
    batch_size=512,
    verbose=1
)

# Evaluate the model on the resized test set
test_loss, test_accuracy = model.evaluate(x_test_resized, y_test, verbose=0)
print(f"Test Accuracy: {test_accuracy * 100:.2f}%")

# %% [markdown]
# # Understanding deep networks
#
# *   What is the use of activation functions in network? Why is it needed?
# *   We have used softmax activation function in the exercise. There are other activation functions available too. What is the difference between sigmoid activation and softmax activation?
# *   What is the difference between categorical crossentropy and binary crossentropy loss?

# %% [markdown]
# **Write the answers below :**
#
# 1 - Use of activation functions:
#
#
#
# _
#
# 2 - Key Differences between sigmoid and softmax:
#
#
#
# _
#
# 3 - Key Differences between categorical crossentropy and binary crossentropy loss:
#
#
# _
